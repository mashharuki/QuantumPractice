# %% [markdown]
# # 重ね合わせとアダマールゲート （理想シミュレータ）

# %% [markdown]
# ## ライブラリのインポート

# %%
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_bloch_multivector

# %% [markdown]
# ## 初期状態が０のとき
# qc0という名前で1キュビット、1ビットの回路を準備

# %%
qc0 = QuantumCircuit(1, 1)

# %% [markdown]
# ### 一つ目のアダマールゲートを追加

# %%
qc0.h(0)

# %% [markdown]
# 回路の確認

# %%
qc0.draw(output='mpl')

# %% [markdown]
# ブロッフォ球で確認

# %%
state_0 = Statevector.from_instruction(qc0)
plot_bloch_multivector(state_0)

# %% [markdown]
# 確率（理論値）ヒストグラムの表示

# %%
counts_0 = state_0.probabilities_dict()
plot_histogram(counts_0)

# %% [markdown]
# ### ２つ目のアダマールゲートを追加

# %%
# 2つ目のHADゲートを追加する。
qc0.h(0)

# %% [markdown]
# 回路の確認

# %%
qc0.draw(output='mpl')

# %% [markdown]
# ブロッフォ球で確認

# %%
state_0 = Statevector.from_instruction(qc0)
plot_bloch_multivector(state_0)

# %% [markdown]
# 確率（理論値）ヒストグラムの表示

# %%
counts_0 = state_0.probabilities_dict()
plot_histogram(counts_0)

# %% [markdown]
# ## 初期状態が１のとき
# qc1という名前で回路を準備

# %%
qc1 = QuantumCircuit(1, 1)

# %% [markdown]
# Xゲートでキュビットを反転し状態を１にする

# %%
# NOTゲートを追加する。
qc1.x(0)

# %% [markdown]
# ### 一つ目のアダマールゲートを追加

# %%
qc1.h(0)

# %% [markdown]
# 回路の確認

# %%
qc1.draw(output='mpl')

# %% [markdown]
# ブロッフォ球で確認

# %%
state_1 = Statevector.from_instruction(qc1)
plot_bloch_multivector(state_1)

# %% [markdown]
# 確率（理論値）ヒストグラムの表示

# %%
counts_1 = state_1.probabilities_dict()
plot_histogram(counts_1)

# %% [markdown]
# ### ２つ目のアダマールゲート追加

# %%
qc1.h(0)

# %% [markdown]
# 回路の確認

# %%
qc1.draw(output='mpl')

# %% [markdown]
# ブロッフォ球で確認

# %%
state_1 = Statevector.from_instruction(qc1)
plot_bloch_multivector(state_1)

# %% [markdown]
# 確率（理論値）ヒストグラムの表示

# %%
counts_1 = state_1.probabilities_dict()
plot_histogram(counts_1)
